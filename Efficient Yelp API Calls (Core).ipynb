# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Load API Credentials
with open('/Users/brookeeagan/.secret/yelp_api.json', 'r') as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s=5.0)

# %%
# set our API call parameters and filename before the first call
location = 'Cincinnati, OH 45202'
term = 'steakhouse'

# %%
location.split(',')[0]
# Out:
# 'Cincinnati'

# %%
## Specify folder for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Cincinnati-steakhouse.json not found. Saving empty list to file.

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
# results datatype
type(results)
# Out:
# dict

# %%
results['total']
# Out:
# 68

# %%
results['businesses']
# Out:
# [{'id': '6aid7C_DAOGd9TQOH3IxQA',
#   'alias': 'mrbl-bellevue',
#   'name': 'Mrbl',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9Pm5gdtAwLLuxKWKMEJrGw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mrbl-bellevue?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 38,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.10359529999995,
#    'longitude': -84.48729379999999},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '119 Fairfield Ave',
#    'address2': 'Ste 427',
#    'address3': None,
#    'city': 'Bellevue',
#    'zip_code': '41073',
#    'country': 'US',
#    'state': 'KY',
#    'display_address': ['119 Fairfield Ave', 'Ste 427', 'Bellevue, KY 41073']},
#   'phone': '+18594316725',
#   'display_phone': '(859) 431-6725',
#   'distance': 705.772769968263},
#  {'id': 'VCjbu4FFX6Ms_ZtWqufrGQ',
#   'alias': 'jeff-rubys-steakhouse-cincinnati-cincinnati',
#   'name': "Jeff Ruby's Steakhouse - Cincinnati",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/306o15Kkk-_ArAAnDb1G1w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jeff-rubys-steakhouse-cincinnati-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 522,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.101555618713, 'longitude': -84.5133238984253},
#   'transactions': ['delivery'],
#   'price': '$$$$',
#   'location': {'address1': '505 Vine St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['505 Vine St', 'Cincinnati, OH 45202']},
#   'phone': '+15137841200',
#   'display_phone': '(513) 784-1200',
#   'distance': 2291.854489675757},
#  {'id': 'TUXdx89o8ytwD4MLZdUSrA',
#   'alias': 'butcher-and-barrel-cincinnati-2',
#   'name': 'Butcher And Barrel',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_ubJNTr2HTI7_9Zf7NW04A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/butcher-and-barrel-cincinnati-2?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 280,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.1035056078084,
#    'longitude': -84.5152342692018},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '700 Race St',
#    'address2': '',
#    'address3': None,
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['700 Race St', 'Cincinnati, OH 45202']},
#   'phone': '+15139548974',
#   'display_phone': '(513) 954-8974',
#   'distance': 2370.9112234554173},
#  {'id': 'vG2t23RU3yQBMlanbn8ZYw',
#   'alias': 'losanti-cincinnati',
#   'name': 'Losanti',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TmQ0qIwzB0How54L9W-Pig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/losanti-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 227,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.11041, 'longitude': -84.51723},
#   'transactions': ['delivery'],
#   'location': {'address1': '1401 Race St',
#    'address2': '',
#    'address3': None,
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1401 Race St', 'Cincinnati, OH 45202']},
#   'phone': '+15132464213',
#   'display_phone': '(513) 246-4213',
#   'distance': 2442.782260001848},
#  {'id': 'E8aPzv11xE7cRKXlNdvVcg',
#   'alias': 'the-precinct-cincinnati',
#   'name': 'The Precinct',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4vBQiB_lmQRyXcM-rCkXrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-precinct-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 549,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.1169783, 'longitude': -84.439863},
#   'transactions': ['delivery'],
#   'price': '$$$$',
#   'location': {'address1': '311 Delta Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45226',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['311 Delta Ave', 'Cincinnati, OH 45226']},
#   'phone': '+15133215454',
#   'display_phone': '(513) 321-5454',
#   'distance': 4312.284238328349},
#  {'id': 'a-hlBRvw8FFPM-G8QSC8Yg',
#   'alias': 'blinkers-tavern-covington',
#   'name': 'Blinkers Tavern',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wykCbc56__NjpqGc6Q3jjw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blinkers-tavern-covington?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 383,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.08829818335, 'longitude': -84.5077985598782},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '318 Greenup St',
#    'address2': '',
#    'address3': '',
#    'city': 'Covington',
#    'zip_code': '41011',
#    'country': 'US',
#    'state': 'KY',
#    'display_address': ['318 Greenup St', 'Covington, KY 41011']},
#   'phone': '+18593600840',
#   'display_phone': '(859) 360-0840',
#   'distance': 2890.6017984155847},
#  {'id': 'zRXMNgaWHeG9374O31QGyw',
#   'alias': 'the-capital-grille-cincinnati-2',
#   'name': 'The Capital Grille',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TXwOJ6j4Xa3h-owQ-A8ZuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-capital-grille-cincinnati-2?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 320,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.14869, 'longitude': -84.44298},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '3821 Edwards Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45209',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['3821 Edwards Rd', 'Cincinnati, OH 45209']},
#   'phone': '+15133510814',
#   'display_phone': '(513) 351-0814',
#   'distance': 5868.5876169116755},
#  {'id': 'J84uf4baM6Kl4r5j4WMK6A',
#   'alias': 'council-oak-steak-and-seafood-cincinnati',
#   'name': 'Council Oak Steak & Seafood',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/16h276pQwAKK8FJdddGbQw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/council-oak-steak-and-seafood-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 22,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.10828, 'longitude': -84.5068},
#   'transactions': [],
#   'location': {'address1': '1000 Broadway St',
#    'address2': '',
#    'address3': None,
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1000 Broadway St', 'Cincinnati, OH 45202']},
#   'phone': '+15132503150',
#   'display_phone': '(513) 250-3150',
#   'distance': 1450.846497638519},
#  {'id': 'S3BZL3CSQ-sqpXpEee62Yg',
#   'alias': 'moerlein-lager-house-cincinnati',
#   'name': 'Moerlein Lager House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hTDzEyFtX8dNgyauispmEA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/moerlein-lager-house-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 1068,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.0963095186957,
#    'longitude': -84.5086569190491},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '115 Joe Nuxhall Way',
#    'address2': '',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['115 Joe Nuxhall Way', 'Cincinnati, OH 45202']},
#   'phone': '+15134212337',
#   'display_phone': '(513) 421-2337',
#   'distance': 2265.8354716269923},
#  {'id': 'pgj9hGkNtxASAncBO3-f0w',
#   'alias': 'lonely-pine-steakhouse-cincinnati',
#   'name': 'The Lonely Pine Steakhouse',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s4kmLMOG6xuXiy6fmLnEDQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lonely-pine-steakhouse-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 84,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.182236, 'longitude': -84.42796},
#   'transactions': ['delivery'],
#   'location': {'address1': '6085 Montgomery Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Cincinnati',
#    'zip_code': '45213',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['6085 Montgomery Rd', 'Cincinnati, OH 45213']},
#   'phone': '+15133511012',
#   'display_phone': '(513) 351-1012',
#   'distance': 9620.693593867305},
#  {'id': '7Qx9wYdQ9w-LFSG4_VFQ6A',
#   'alias': 'prime-cincinnati-cincinnati',
#   'name': 'Prime Cincinnati',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bHIAQF6qHlzPYfmZpWZrnQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prime-cincinnati-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 322,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.1025924881286,
#    'longitude': -84.5113296537306},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '580 Walnut St',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['580 Walnut St', 'Ste 100', 'Cincinnati, OH 45202']},
#   'phone': '+15135790720',
#   'display_phone': '(513) 579-0720',
#   'distance': 2088.3281412277256},
#  {'id': 'rcqsLyu6dKuL-mg8ys0RuQ',
#   'alias': 'buckhead-mountain-grill-bellevue',
#   'name': 'Buckhead Mountain Grill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/evczK3aCyDLqIiSEggJPxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/buckhead-mountain-grill-bellevue?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 330,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.103360173447, 'longitude': -84.488563317322},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '35 Fairfield Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bellevue',
#    'zip_code': '41073',
#    'country': 'US',
#    'state': 'KY',
#    'display_address': ['35 Fairfield Ave', 'Bellevue, KY 41073']},
#   'phone': '+18594917333',
#   'display_phone': '(859) 491-7333',
#   'distance': 717.6160065658348},
#  {'id': 'eDQP1l7FtqlXP0v2wIky_Q',
#   'alias': 'boca-cincinnati-2',
#   'name': 'Boca',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BPwCNjBUDLkLQ_bBOUmFmg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boca-cincinnati-2?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 575,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'french', 'title': 'French'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.10296, 'longitude': -84.5112599},
#   'transactions': ['delivery'],
#   'price': '$$$$',
#   'location': {'address1': '114 E 6th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['114 E 6th St', 'Cincinnati, OH 45202']},
#   'phone': '+15135422022',
#   'display_phone': '(513) 542-2022',
#   'distance': 2062.1977778536384},
#  {'id': 'GbLcYwPYgIVJtwm_j4XpAA',
#   'alias': 'chart-house-newport',
#   'name': 'Chart House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R3OSY3pUckJEGgnGEoGaVQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chart-house-newport?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 207,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.1016112343782,
#    'longitude': -84.4900191575289},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '405 Riverboat Row',
#    'address2': '',
#    'address3': '',
#    'city': 'Newport',
#    'zip_code': '41071',
#    'country': 'US',
#    'state': 'KY',
#    'display_address': ['405 Riverboat Row', 'Newport, KY 41071']},
#   'phone': '+18592610300',
#   'display_phone': '(859) 261-0300',
#   'distance': 915.5484822199003},
#  {'id': 'HZlIF0Reb35VIslWSp0bcQ',
#   'alias': 'salazar-restaurant-chef-jose-salazar-otr-restaurant-and-bar-cincinnati',
#   'name': 'Salazar Restaurant * Chef Jose Salazar | OTR Restaurant & Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/56JZfjeXkY2cSKDm-VQ7Tg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/salazar-restaurant-chef-jose-salazar-otr-restaurant-and-bar-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 392,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.1105463, 'longitude': -84.516384},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '1401 Republic St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['1401 Republic St', 'Cincinnati, OH 45202']},
#   'phone': '+15136217000',
#   'display_phone': '(513) 621-7000',
#   'distance': 2365.575549315515},
#  {'id': 'xqWDIdt9esvxsqYnTL7aQA',
#   'alias': 'j-alexanders-restaurant-cincinnati-2',
#   'name': "J. Alexander's Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iIuS0FRcFjPX6QPLxJPlkA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/j-alexanders-restaurant-cincinnati-2?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 260,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.14867, 'longitude': -84.44468},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2629 Edmondon Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45209',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['2629 Edmondon Rd', 'Cincinnati, OH 45209']},
#   'phone': '+15135317495',
#   'display_phone': '(513) 531-7495',
#   'distance': 5763.886825625213},
#  {'id': 'X6rUhhPt4uyLCrQenboYQQ',
#   'alias': 'ruths-chris-steak-house-cincinnati-2',
#   'name': "Ruth's Chris Steak House",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3K1nEoX3zUBDTWVJOGft5w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ruths-chris-steak-house-cincinnati-2?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 299,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.0974179861526,
#    'longitude': -84.5101270079612},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$$',
#   'location': {'address1': '100 E Freedom Way #160',
#    'address2': 'Ste 160',
#    'address3': 'The Banks Development',
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['100 E Freedom Way #160',
#     'Ste 160',
#     'The Banks Development',
#     'Cincinnati, OH 45202']},
#   'phone': '+15133810491',
#   'display_phone': '(513) 381-0491',
#   'distance': 2286.0435362000694},
#  {'id': 'kvSEn3cyJHArhCUxQBld4A',
#   'alias': 'montgomery-inn-the-boathouse-cincinnati',
#   'name': 'Montgomery Inn - The Boathouse',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Xa3iv66CiKyDE6bOLWE8HQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/montgomery-inn-the-boathouse-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 661,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.10390124596287,
#    'longitude': -84.49456487050533},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '925 Riverside Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['925 Riverside Dr', 'Cincinnati, OH 45202']},
#   'phone': '+15137217427',
#   'display_phone': '(513) 721-7427',
#   'distance': 814.2425452541953},
#  {'id': 'j1d_m7K4y_X2dPhaK2HYPQ',
#   'alias': 'mortons-the-steakhouse-cincinnati',
#   'name': "Morton's The Steakhouse",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DR4qrXkZPOGT7LaCBIU0EA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mortons-the-steakhouse-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 208,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.1009583432751,
#    'longitude': -84.5130888372659},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$$',
#   'location': {'address1': '441 Vine St',
#    'address2': 'Ste 1h',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['441 Vine St', 'Ste 1h', 'Cincinnati, OH 45202']},
#   'phone': '+15136213111',
#   'display_phone': '(513) 621-3111',
#   'distance': 2300.8934307911627},
#  {'id': 'q_NvSi3WwiAOhQNlpH99GA',
#   'alias': 'nicholsons-cincinnati',
#   'name': "Nicholson's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4XfORuGDQ5jydlAPWPMVMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nicholsons-cincinnati?adjust_creative=A8V0XoEk418xlgiPLONTXg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=A8V0XoEk418xlgiPLONTXg',
#   'review_count': 493,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.1033601814341,
#    'longitude': -84.5120372489765},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '625 Walnut St',
#    'address2': '',
#    'address3': '',
#    'city': 'Cincinnati',
#    'zip_code': '45202',
#    'country': 'US',
#    'state': 'OH',
#    'display_address': ['625 Walnut St', 'Cincinnati, OH 45202']},
#   'phone': '+15135649111',
#   'display_phone': '(513) 564-9111',
#   'distance': 2114.379003350312}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                              alias  \
# 0   6aid7C_DAOGd9TQOH3IxQA                                      mrbl-bellevue
# 1   VCjbu4FFX6Ms_ZtWqufrGQ        jeff-rubys-steakhouse-cincinnati-cincinnati
# 2   TUXdx89o8ytwD4MLZdUSrA                    butcher-and-barrel-cincinnati-2
# 3   vG2t23RU3yQBMlanbn8ZYw                                 losanti-cincinnati
# 4   E8aPzv11xE7cRKXlNdvVcg                            the-precinct-cincinnati
# 5   a-hlBRvw8FFPM-G8QSC8Yg                          blinkers-tavern-covington
# 6   zRXMNgaWHeG9374O31QGyw                    the-capital-grille-cincinnati-2
# 7   J84uf4baM6Kl4r5j4WMK6A           council-oak-steak-and-seafood-cincinnati
# 8   S3BZL3CSQ-sqpXpEee62Yg                    moerlein-lager-house-cincinnati
# 9   pgj9hGkNtxASAncBO3-f0w                  lonely-pine-steakhouse-cincinnati
# 10  7Qx9wYdQ9w-LFSG4_VFQ6A                        prime-cincinnati-cincinnati
# 11  rcqsLyu6dKuL-mg8ys0RuQ                   buckhead-mountain-grill-bellevue
# 12  eDQP1l7FtqlXP0v2wIky_Q                                  boca-cincinnati-2
# 13  GbLcYwPYgIVJtwm_j4XpAA                                chart-house-newport
# 14  HZlIF0Reb35VIslWSp0bcQ  salazar-restaurant-chef-jose-salazar-otr-resta...
# 15  xqWDIdt9esvxsqYnTL7aQA               j-alexanders-restaurant-cincinnati-2
# 16  X6rUhhPt4uyLCrQenboYQQ               ruths-chris-steak-house-cincinnati-2
# 17  kvSEn3cyJHArhCUxQBld4A            montgomery-inn-the-boathouse-cincinnati
# 18  j1d_m7K4y_X2dPhaK2HYPQ                  mortons-the-steakhouse-cincinnati
# 19  q_NvSi3WwiAOhQNlpH99GA                              nicholsons-cincinnati
#
#                                                  name  \
# 0                                                Mrbl
# 1                 Jeff Ruby's Steakhouse - Cincinnati
# 2                                  Butcher And Barrel
# 3                                             Losanti
# 4                                        The Precinct
# 5                                     Blinkers Tavern
# 6                                  The Capital Grille
# 7                         Council Oak Steak & Seafood
# 8                                Moerlein Lager House
# 9                          The Lonely Pine Steakhouse
# 10                                   Prime Cincinnati
# 11                            Buckhead Mountain Grill
# 12                                               Boca
# 13                                        Chart House
# 14  Salazar Restaurant * Chef Jose Salazar | OTR R...
# 15                          J. Alexander's Restaurant
# 16                           Ruth's Chris Steak House
# 17                     Montgomery Inn - The Boathouse
# 18                            Morton's The Steakhouse
# 19                                        Nicholson's
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/9Pm5gd...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/306o15...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/_ubJNT...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/TmQ0qI...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/4vBQiB...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/wykCbc...      False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/TXwOJ6...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/16h276...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/hTDzEy...      False
# 9   https://s3-media1.fl.yelpcdn.com/bphoto/s4kmLM...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/bHIAQF...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/evczK3...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/BPwCNj...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/R3OSY3...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/56JZfj...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/iIuS0F...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/3K1nEo...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/Xa3iv6...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/DR4qrX...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/4XfORu...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/mrbl-bellevue?adjust_...            38
# 1   https://www.yelp.com/biz/jeff-rubys-steakhouse...           522
# 2   https://www.yelp.com/biz/butcher-and-barrel-ci...           280
# 3   https://www.yelp.com/biz/losanti-cincinnati?ad...           227
# 4   https://www.yelp.com/biz/the-precinct-cincinna...           549
# 5   https://www.yelp.com/biz/blinkers-tavern-covin...           383
# 6   https://www.yelp.com/biz/the-capital-grille-ci...           320
# 7   https://www.yelp.com/biz/council-oak-steak-and...            22
# 8   https://www.yelp.com/biz/moerlein-lager-house-...          1068
# 9   https://www.yelp.com/biz/lonely-pine-steakhous...            84
# 10  https://www.yelp.com/biz/prime-cincinnati-cinc...           322
# 11  https://www.yelp.com/biz/buckhead-mountain-gri...           330
# 12  https://www.yelp.com/biz/boca-cincinnati-2?adj...           575
# 13  https://www.yelp.com/biz/chart-house-newport?a...           207
# 14  https://www.yelp.com/biz/salazar-restaurant-ch...           392
# 15  https://www.yelp.com/biz/j-alexanders-restaura...           260
# 16  https://www.yelp.com/biz/ruths-chris-steak-hou...           299
# 17  https://www.yelp.com/biz/montgomery-inn-the-bo...           661
# 18  https://www.yelp.com/biz/mortons-the-steakhous...           208
# 19  https://www.yelp.com/biz/nicholsons-cincinnati...           493
#
#                                            categories  rating  \
# 0   [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.0
# 1        [{'alias': 'steak', 'title': 'Steakhouses'}]     4.5
# 2   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 3   [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.5
# 4        [{'alias': 'steak', 'title': 'Steakhouses'}]     4.5
# 5   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 6   [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.5
# 7   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 8   [{'alias': 'newamerican', 'title': 'American (...     4.0
# 9   [{'alias': 'tradamerican', 'title': 'American ...     4.5
# 10  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     3.5
# 11  [{'alias': 'tradamerican', 'title': 'American ...     3.0
# 12  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 13  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.0
# 14  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 15  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     3.5
# 16  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     3.5
# 17  [{'alias': 'tradamerican', 'title': 'American ...     3.5
# 18  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     3.5
# 19  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 39.10359529999995, 'longitude': -...                  []
# 1   {'latitude': 39.101555618713, 'longitude': -84...          [delivery]
# 2   {'latitude': 39.1035056078084, 'longitude': -8...          [delivery]
# 3      {'latitude': 39.11041, 'longitude': -84.51723}          [delivery]
# 4   {'latitude': 39.1169783, 'longitude': -84.439863}          [delivery]
# 5   {'latitude': 39.08829818335, 'longitude': -84....          [delivery]
# 6      {'latitude': 39.14869, 'longitude': -84.44298}                  []
# 7       {'latitude': 39.10828, 'longitude': -84.5068}                  []
# 8   {'latitude': 39.0963095186957, 'longitude': -8...          [delivery]
# 9     {'latitude': 39.182236, 'longitude': -84.42796}          [delivery]
# 10  {'latitude': 39.1025924881286, 'longitude': -8...          [delivery]
# 11  {'latitude': 39.103360173447, 'longitude': -84...  [pickup, delivery]
# 12   {'latitude': 39.10296, 'longitude': -84.5112599}          [delivery]
# 13  {'latitude': 39.1016112343782, 'longitude': -8...  [pickup, delivery]
# 14  {'latitude': 39.1105463, 'longitude': -84.516384}          [delivery]
# 15     {'latitude': 39.14867, 'longitude': -84.44468}          [delivery]
# 16  {'latitude': 39.0974179861526, 'longitude': -8...  [pickup, delivery]
# 17  {'latitude': 39.10390124596287, 'longitude': -...          [delivery]
# 18  {'latitude': 39.1009583432751, 'longitude': -8...  [pickup, delivery]
# 19  {'latitude': 39.1033601814341, 'longitude': -8...          [delivery]
#
#    price                                           location         phone  \
# 0    $$$  {'address1': '119 Fairfield Ave', 'address2': ...  +18594316725
# 1   $$$$  {'address1': '505 Vine St', 'address2': '', 'a...  +15137841200
# 2     $$  {'address1': '700 Race St', 'address2': '', 'a...  +15139548974
# 3    NaN  {'address1': '1401 Race St', 'address2': '', '...  +15132464213
# 4   $$$$  {'address1': '311 Delta Ave', 'address2': '', ...  +15133215454
# 5     $$  {'address1': '318 Greenup St', 'address2': '',...  +18593600840
# 6    $$$  {'address1': '3821 Edwards Rd', 'address2': ''...  +15133510814
# 7    NaN  {'address1': '1000 Broadway St', 'address2': '...  +15132503150
# 8     $$  {'address1': '115 Joe Nuxhall Way', 'address2'...  +15134212337
# 9    NaN  {'address1': '6085 Montgomery Rd', 'address2':...  +15133511012
# 10   $$$  {'address1': '580 Walnut St', 'address2': 'Ste...  +15135790720
# 11    $$  {'address1': '35 Fairfield Ave', 'address2': '...  +18594917333
# 12  $$$$  {'address1': '114 E 6th St', 'address2': '', '...  +15135422022
# 13   $$$  {'address1': '405 Riverboat Row', 'address2': ...  +18592610300
# 14   $$$  {'address1': '1401 Republic St', 'address2': '...  +15136217000
# 15    $$  {'address1': '2629 Edmondon Rd', 'address2': '...  +15135317495
# 16  $$$$  {'address1': '100 E Freedom Way #160', 'addres...  +15133810491
# 17    $$  {'address1': '925 Riverside Dr', 'address2': '...  +15137217427
# 18  $$$$  {'address1': '441 Vine St', 'address2': 'Ste 1...  +15136213111
# 19    $$  {'address1': '625 Walnut St', 'address2': '', ...  +15135649111
#
#      display_phone     distance
# 0   (859) 431-6725   705.772770
# 1   (513) 784-1200  2291.854490
# 2   (513) 954-8974  2370.911223
# 3   (513) 246-4213  2442.782260
# 4   (513) 321-5454  4312.284238
# 5   (859) 360-0840  2890.601798
# 6   (513) 351-0814  5868.587617
# 7   (513) 250-3150  1450.846498
# 8   (513) 421-2337  2265.835472
# 9   (513) 351-1012  9620.693594
# 10  (513) 579-0720  2088.328141
# 11  (859) 491-7333   717.616007
# 12  (513) 542-2022  2062.197778
# 13  (859) 261-0300   915.548482
# 14  (513) 621-7000  2365.575549
# 15  (513) 531-7495  5763.886826
# 16  (513) 381-0491  2286.043536
# 17  (513) 721-7427   814.242545
# 18  (513) 621-3111  2300.893431
# 19  (513) 564-9111  2114.379003

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 4

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term, offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print('[!] Error: ', e)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
df = pd.read_json(JSON_FILE)
df
# Out:
#                         id                                        alias  \
# 0   VCjbu4FFX6Ms_ZtWqufrGQ  jeff-rubys-steakhouse-cincinnati-cincinnati
# 1   TUXdx89o8ytwD4MLZdUSrA              butcher-and-barrel-cincinnati-2
# 2   vG2t23RU3yQBMlanbn8ZYw                           losanti-cincinnati
# 3   E8aPzv11xE7cRKXlNdvVcg                      the-precinct-cincinnati
# 4   a-hlBRvw8FFPM-G8QSC8Yg                    blinkers-tavern-covington
# ..                     ...                                          ...
# 62  Ih1pras9IeVS1aHQjMrapA              overlook-kitchen-bar-cincinnati
# 63  ebbcgoMl0F7larlD7DQeTA                         zips-cafe-cincinnati
# 64  lKUVzQY-RZkqiSh_qtTgmg      ft-wright-family-restaurant-fort-wright
# 65  fjCVWMoqSMaN1XSaq911dw                          bob-evans-ft-wright
# 66  ZWEeKsNolg5QiZPIiJwk0A                            ihop-cincinnati-6
#
#                                    name  \
# 0   Jeff Ruby's Steakhouse - Cincinnati
# 1                    Butcher And Barrel
# 2                               Losanti
# 3                          The Precinct
# 4                       Blinkers Tavern
# ..                                  ...
# 62               Overlook Kitchen + Bar
# 63                           Zip's Cafe
# 64          Ft Wright Family Restaurant
# 65                            Bob Evans
# 66                                 IHOP
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/306o15...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/_ubJNT...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/TmQ0qI...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/4vBQiB...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/wykCbc...      False
# ..                                                ...        ...
# 62  https://s3-media2.fl.yelpcdn.com/bphoto/z4ylqc...      False
# 63  https://s3-media2.fl.yelpcdn.com/bphoto/OKxKHx...      False
# 64  https://s3-media2.fl.yelpcdn.com/bphoto/B9J-xm...      False
# 65  https://s3-media3.fl.yelpcdn.com/bphoto/K6Av3j...      False
# 66  https://s3-media1.fl.yelpcdn.com/bphoto/mSFXRj...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/jeff-rubys-steakhouse...           522
# 1   https://www.yelp.com/biz/butcher-and-barrel-ci...           280
# 2   https://www.yelp.com/biz/losanti-cincinnati?ad...           227
# 3   https://www.yelp.com/biz/the-precinct-cincinna...           549
# 4   https://www.yelp.com/biz/blinkers-tavern-covin...           383
# ..                                                ...           ...
# 62  https://www.yelp.com/biz/overlook-kitchen-bar-...            52
# 63  https://www.yelp.com/biz/zips-cafe-cincinnati?...           420
# 64  https://www.yelp.com/biz/ft-wright-family-rest...           107
# 65  https://www.yelp.com/biz/bob-evans-ft-wright?a...            38
# 66  https://www.yelp.com/biz/ihop-cincinnati-6?adj...           127
#
#                                            categories  rating  \
# 0        [{'alias': 'steak', 'title': 'Steakhouses'}]     4.5
# 1   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 2   [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.5
# 3        [{'alias': 'steak', 'title': 'Steakhouses'}]     4.5
# 4   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# ..                                                ...     ...
# 62  [{'alias': 'newamerican', 'title': 'American (...     3.5
# 63  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.0
# 64  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 65  [{'alias': 'breakfast_brunch', 'title': 'Break...     3.0
# 66  [{'alias': 'breakfast_brunch', 'title': 'Break...     1.5
#
#                                           coordinates        transactions  \
# 0   {'latitude': 39.101555618713, 'longitude': -84...          [delivery]
# 1   {'latitude': 39.1035056078084, 'longitude': -8...          [delivery]
# 2      {'latitude': 39.11041, 'longitude': -84.51723}          [delivery]
# 3   {'latitude': 39.1169783, 'longitude': -84.439863}          [delivery]
# 4   {'latitude': 39.08829818335, 'longitude': -84....          [delivery]
# ..                                                ...                 ...
# 62      {'latitude': 39.1588, 'longitude': -84.40312}  [pickup, delivery]
# 63  {'latitude': 39.129714, 'longitude': -84.42940...          [delivery]
# 64  {'latitude': 39.0607081353664, 'longitude': -8...  [pickup, delivery]
# 65  {'latitude': 39.0314953, 'longitude': -84.5348...  [pickup, delivery]
# 66       {'latitude': 39.164, 'longitude': -84.42543}  [pickup, delivery]
#
#    price                                           location         phone  \
# 0   $$$$  {'address1': '505 Vine St', 'address2': '', 'a...  +15137841200
# 1     $$  {'address1': '700 Race St', 'address2': '', 'a...  +15139548974
# 2    NaN  {'address1': '1401 Race St', 'address2': '', '...  +15132464213
# 3   $$$$  {'address1': '311 Delta Ave', 'address2': '', ...  +15133215454
# 4     $$  {'address1': '318 Greenup St', 'address2': '',...  +18593600840
# ..   ...                                                ...           ...
# 62   NaN  {'address1': '5345 Medpace Way', 'address2': '...  +15135279906
# 63    $$  {'address1': '1036 Delta Ave', 'address2': '',...  +15138719876
# 64     $  {'address1': '1860 Ashwood Cir', 'address2': '...  +18593318359
# 65     $  {'address1': '489 Orphanage Rd', 'address2': '...  +18595789840
# 66     $  {'address1': '4825 Marburg Ave', 'address2': '...  +15137313666
#
#      display_phone     distance
# 0   (513) 784-1200  2291.854490
# 1   (513) 954-8974  2370.911223
# 2   (513) 246-4213  2442.782260
# 3   (513) 321-5454  4312.284238
# 4   (859) 360-0840  2890.601798
# ..             ...          ...
# 62  (513) 527-9906  9158.968538
# 63  (513) 871-9876  5596.521993
# 64  (859) 331-8359  7101.621294
# 65  (859) 578-9840  9566.615504
# 66  (513) 731-3666  8146.083268
#
# [67 rows x 16 columns]

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Cincinnati-steakhouse.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression='gzip', index=False)

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 67,668 Bytes
# CSV.GZ FILE: 10,446 Bytes
# the csv.gz is 6.477886272257323 times smaller!
